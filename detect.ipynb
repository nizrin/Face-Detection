# %%
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread("cc.jpg")
img
# Out:
# array([[[55, 73, 74],
#         [43, 61, 62],
#         [45, 64, 69],
#         ...,
#         [23, 22, 18],
#         [23, 22, 18],
#         [23, 22, 18]],
#
#        [[45, 60, 62],
#         [34, 52, 53],
#         [41, 58, 61],
#         ...,
#         [23, 22, 18],
#         [23, 22, 18],
#         [23, 22, 18]],
#
#        [[39, 53, 52],
#         [30, 45, 47],
#         [36, 53, 56],
#         ...,
#         [23, 22, 18],
#         [23, 22, 18],
#         [23, 22, 18]],
#
#        ...,
#
#        [[12, 12,  6],
#         [12, 12,  6],
#         [12, 12,  6],
#         ...,
#         [13, 15, 15],
#         [10, 12, 12],
#         [10, 12, 12]],
#
#        [[11, 11,  5],
#         [11, 11,  5],
#         [12, 12,  6],
#         ...,
#         [11, 13, 13],
#         [11, 13, 13],
#         [11, 13, 13]],
#
#        [[11, 11,  5],
#         [11, 11,  5],
#         [12, 12,  6],
#         ...,
#         [10, 12, 12],
#         [11, 13, 13],
#         [12, 14, 14]]], shape=(360, 540, 3), dtype=uint8)

# %%
plt.imshow(img)

# %%
conv_img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(conv_img)

# %% [markdown]
# Object creation of a pretrained classifier

# %%
face_cas=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
face_cas
# Out:
# < cv2.CascadeClassifier 000002390DD2A950>

# %%
faces=face_cas.detectMultiScale(conv_img,minNeighbors=15)
faces
# Out:
# array([[149,  57,  70,  70],
#        [314,  51,  76,  76]], dtype=int32)

# %%
for(x,y,w,h) in faces:
    cv2.rectangle(conv_img,(x,y),(x+w,y+h),(0,0,255),4)

# %%
plt.imshow(conv_img)

# %%
video=cv2.VideoCapture("video.mp4")
while True:
    sucess,img=video.read()
    gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces=face_cas.detectMultiScale(gray,minNeighbors=8)
    for(x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,255),3)
    cv2.imshow("IMAGES",img)
    if cv2.waitKey(1) & 0xFF==ord('q'):
        break
video.release()
cv2.destroyAllWindows()
